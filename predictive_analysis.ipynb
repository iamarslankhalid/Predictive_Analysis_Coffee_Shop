# %% [markdown]
# # PREDICTIVE ANALYSIS COFFEE SHOP SALES

# %% [markdown]
# ## Load the Dataset and Initial Inspection

# %%
import pandas as pd

# Load the dataset
data = pd.read_excel("Coffee Shop Sales.xlsx")

# %% [markdown]
# ### Initial inspection

# %%
print(data.head())
# Out:
#    transaction_id transaction_date transaction_time  transaction_qty  \
# 0               1       2023-01-01         07:06:11                2
# 1               2       2023-01-01         07:08:56                2
# 2               3       2023-01-01         07:14:04                2
# 3               4       2023-01-01         07:20:24                1
# 4               5       2023-01-01         07:22:41                2
#
#    store_id   store_location  product_id  unit_price    product_category  \
# 0         5  Lower Manhattan          32         3.0              Coffee
# 1         5  Lower Manhattan          57         3.1                 Tea
# 2         5  Lower Manhattan          59         4.5  Drinking Chocolate
# 3         5  Lower Manhattan          22         2.0              Coffee
# 4         5  Lower Manhattan          57         3.1                 Tea
#
#             product_type               product_detail
# 0  Gourmet brewed coffee                  Ethiopia Rg
# ...

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149116 entries, 0 to 149115
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   transaction_id    149116 non-null  int64
#  1   transaction_date  149116 non-null  datetime64[ns]
#  2   transaction_time  149116 non-null  object
#  3   transaction_qty   149116 non-null  int64
#  4   store_id          149116 non-null  int64
#  5   store_location    149116 non-null  object
#  6   product_id        149116 non-null  int64
#  7   unit_price        149116 non-null  float64
#  8   product_category  149116 non-null  object
#  9   product_type      149116 non-null  object
#  10  product_detail    149116 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(4), object(5)
# memory usage: 12.5+ MB
# None

# %%
print(data.shape)
# Out:
# (149116, 11)

# %%
print(data.describe())
# Out:
#        transaction_id               transaction_date  transaction_qty  \
# count   149116.000000                         149116    149116.000000
# mean     74737.371872  2023-04-15 11:50:32.173609984         1.438276
# min          1.000000            2023-01-01 00:00:00         1.000000
# 25%      37335.750000            2023-03-06 00:00:00         1.000000
# 50%      74727.500000            2023-04-24 00:00:00         1.000000
# 75%     112094.250000            2023-05-30 00:00:00         2.000000
# max     149456.000000            2023-06-30 00:00:00         8.000000
# std      43153.600016                            NaN         0.542509
#
#             store_id     product_id     unit_price
# count  149116.000000  149116.000000  149116.000000
# mean        5.342063      47.918607       3.382219
# min         3.000000       1.000000       0.800000
# 25%         3.000000      33.000000       2.500000
# 50%         5.000000      47.000000       3.000000
# ...

# %% [markdown]
# ## Data Cleaning

# %%
# Check for missing values
missing_values = data.isnull().sum()
print("Missing values in each column:")
print(missing_values)
# Out:
# Missing values in each column:
# transaction_id      0
# transaction_date    0
# transaction_time    0
# transaction_qty     0
# store_id            0
# store_location      0
# product_id          0
# unit_price          0
# product_category    0
# product_type        0
# product_detail      0
# dtype: int64

# %%
# Remove duplicates
duplicates = data.duplicated().sum()
data_cleaned = data.drop_duplicates()
print(f"Duplicates found: {duplicates}")
print(f"Shape after removing duplicates: {data_cleaned.shape}")
# Out:
# Duplicates found: 0
# Shape after removing duplicates: (149116, 11)

# %%
# Convert all non-string values in object columns to strings
for col in data_cleaned.select_dtypes(include=['object']).columns:
    data_cleaned[col] = data_cleaned[col].astype(str)

# %%
# Strip leading/trailing spaces from object type columns
for col in data_cleaned.select_dtypes(include=['object']).columns:
    data_cleaned[col] = data_cleaned[col].str.strip()

# %%
# Display cleaned data info
print(data_cleaned.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149116 entries, 0 to 149115
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   transaction_id    149116 non-null  int64
#  1   transaction_date  149116 non-null  datetime64[ns]
#  2   transaction_time  149116 non-null  object
#  3   transaction_qty   149116 non-null  int64
#  4   store_id          149116 non-null  int64
#  5   store_location    149116 non-null  object
#  6   product_id        149116 non-null  int64
#  7   unit_price        149116 non-null  float64
#  8   product_category  149116 non-null  object
#  9   product_type      149116 non-null  object
#  10  product_detail    149116 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(4), object(5)
# memory usage: 12.5+ MB
# None

# %%
# Check for outliers in numerical columns
print(data_cleaned.describe())
# Out:
#        transaction_id               transaction_date  transaction_qty  \
# count   149116.000000                         149116    149116.000000
# mean     74737.371872  2023-04-15 11:50:32.173609984         1.438276
# min          1.000000            2023-01-01 00:00:00         1.000000
# 25%      37335.750000            2023-03-06 00:00:00         1.000000
# 50%      74727.500000            2023-04-24 00:00:00         1.000000
# 75%     112094.250000            2023-05-30 00:00:00         2.000000
# max     149456.000000            2023-06-30 00:00:00         8.000000
# std      43153.600016                            NaN         0.542509
#
#             store_id     product_id     unit_price
# count  149116.000000  149116.000000  149116.000000
# mean        5.342063      47.918607       3.382219
# min         3.000000       1.000000       0.800000
# 25%         3.000000      33.000000       2.500000
# 50%         5.000000      47.000000       3.000000
# ...

# %%
# Convert 'transaction_time' to proper time format
data_cleaned['transaction_time'] = pd.to_datetime(data_cleaned['transaction_time'], format='%H:%M:%S', errors='coerce').dt.time

# %%
# Display cleaned data info again to ensure all changes are applied
print(data_cleaned.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149116 entries, 0 to 149115
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   transaction_id    149116 non-null  int64
#  1   transaction_date  149116 non-null  datetime64[ns]
#  2   transaction_time  149116 non-null  object
#  3   transaction_qty   149116 non-null  int64
#  4   store_id          149116 non-null  int64
#  5   store_location    149116 non-null  object
#  6   product_id        149116 non-null  int64
#  7   unit_price        149116 non-null  float64
#  8   product_category  149116 non-null  object
#  9   product_type      149116 non-null  object
#  10  product_detail    149116 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(4), object(5)
# memory usage: 12.5+ MB
# None

# %%
# Save the cleaned dataset for further analysis
data_cleaned.to_excel("Cleaned_Coffee_Shop_Sales.xlsx", index=False)

# %% [markdown]
# ## Profit/Loss Analysis

# %% [markdown]
# In this step, we will:
# - Calculate the total sales, costs, and profit for each product/service.
# - Visualize the sales data.
# - Identify products/services generating profit and those incurring losses.
#
# **Calculating Total Sales, Costs, and Profit**
#
# To perform these calculations, we need to make some assumptions:
#
# - **Total Sales:** transaction_qty * unit_price
# - **Cost:** Assuming a fixed cost per unit, we might need additional data or an assumption for the cost. For this example, let's assume a generic cost, say 70% of the unit price (this can be adjusted based on actual cost data if available).

# %% [markdown]
# ### Implementing the Calculations

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Add a column for total sales
data_cleaned['total_sales'] = data_cleaned['transaction_qty'] * data_cleaned['unit_price']

# %%
# Assuming cost is 70% of the unit price for simplicity
data_cleaned['cost'] = data_cleaned['transaction_qty'] * (data_cleaned['unit_price'] * 0.7)

# %%
# Calculate profit
data_cleaned['profit'] = data_cleaned['total_sales'] - data_cleaned['cost']

# %%
# Group by product details to get aggregated sales, cost, and profit
product_performance = data_cleaned.groupby('product_detail').agg({
    'total_sales': 'sum',
    'cost': 'sum',
    'profit': 'sum'
}).reset_index()

# %%
# Identify products generating profit and those incurring losses
profitable_products = product_performance[product_performance['profit'] > 0]
loss_making_products = product_performance[product_performance['profit'] <= 0]

# %%
# Plotting total sales and profit for each product
plt.figure(figsize=(14, 7))
sns.barplot(x='total_sales', y='product_detail', data=product_performance.sort_values(by='total_sales', ascending=False))
plt.title('Total Sales by Product')
plt.xlabel('Total Sales')
plt.ylabel('Product Detail')
plt.show()

# %%
## Plotting profit for each product
plt.figure(figsize=(14, 7))
sns.barplot(x='profit', y='product_detail', data=product_performance.sort_values(by='profit', ascending=False))
plt.title('Profit by Product')
plt.xlabel('Profit')
plt.ylabel('Product Detail')
plt.show()

# %%
# Display the product performance data
product_performance.head()
# Out:
#         product_detail  total_sales       cost    profit
# 0     Almond Croissant      7168.13   5017.691  2150.439
# 1  Brazilian - Organic      3852.00   2696.400  1155.600
# 2         Brazilian Lg     15109.50  10576.650  4532.850
# 3         Brazilian Rg     13155.00   9208.500  3946.500
# 4         Brazilian Sm      9482.00   6637.400  2844.600

# %% [markdown]
# ## Summary of Analysis
#
# ##### 1. Profitable Products:
# - Products generating positive profit.
#
# ##### 2. Loss-Making Products:
# - Products generating negative profit.
#
# ### Recommendations
#
# ##### 1. Profit Increase:
# - Focus on high-selling products.
# - Upsell and cross-sell.
# - Reduce costs.
#
# ##### 2. Loss Mitigation:
# - Analyze loss-making products.
# - Improve product quality.
# - Targeted promotions.

# %% [markdown]
# ## Profit Increase Prediction

# %% [markdown]
# ## Predictive Modeling

# %% [markdown]
# We'll use Linear Regression to forecast future profits. This involves:
#
# 1. Preparing the data for modeling.
# 2. Splitting the data into training and testing sets.
# 3. Training the model.
# 4. Evaluating the model's performance.
# 5. Making predictions.

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
# Prepare the data
# We'll use 'transaction_qty', 'unit_price', and 'total_sales' as features for simplicity
features = data_cleaned[['transaction_qty', 'unit_price', 'total_sales']]
target = data_cleaned['profit']

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# %%
# Initialize and train the model
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Make predictions
y_pred = model.predict(X_test)

# %%
# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

mse, r2
# Out:
# (3.661929745623797e-30, 1.0)

# %% [markdown]
# ## Exploring Factors Contributing to Profitability
# We will analyze the coefficients of the Linear Regression model to understand the impact of each feature on profitability.

# %%
# Get the model coefficients
coefficients = pd.DataFrame({
    'Feature': features.columns,
    'Coefficient': model.coef_
})

coefficients
# Out:
#            Feature   Coefficient
# 0  transaction_qty  5.681449e-15
# 1       unit_price  2.664535e-15
# 2      total_sales  3.000000e-01

# %% [markdown]
# ## Recommendations
#
# Based on the model's predictions and coefficients, we can provide the following recommendations to increase profit margins:
#
# **1. Optimize Pricing Strategies:**
# - Adjust unit prices to maximize profits based on the model's insights.
#
# **2. Increase Sales Volume:**
# - Implement marketing strategies to boost transaction quantities, especially for products with higher profit margins.
#
# **3. Focus on High-Profit Products:**
# - Prioritize products with higher coefficients (positive impact on profit).

# %% [markdown]
# ## Identify Products with Potential for Increased Profit
# Use the model to predict future profits and identify products that can significantly increase profit.

# %%
# Predict future profits for all products
data_cleaned['predicted_profit'] = model.predict(features)

# Identify products with the highest potential for increased profit
high_potential_products = data_cleaned.groupby('product_detail').agg({
    'predicted_profit': 'mean'
}).reset_index().sort_values(by='predicted_profit', ascending=False)

high_potential_products.head(10)  # Display top 10 products with the highest predicted profit
# Out:
#                product_detail  predicted_profit
# 12                  Civet Cat         18.473684
# 41    I Need My Bean! T-shirt          8.366063
# 56        Organic Decaf Blend          6.782767
# 30                   Ethiopia          6.300000
# 65       Primo Espresso Roast          6.135000
# 42      Jamacian Coffee River          5.925000
# 1         Brazilian - Organic          5.529187
# 57   Our Old Time Diner Blend          5.400000
# 13     Columbian Medium Roast          4.500000
# 40  I Need My Bean! Latte cup          4.449671
